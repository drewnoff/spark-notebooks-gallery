// %% [markdown]
// #Analyzing physical activity monitor data

// %% [markdown]
// TODO intro

// %% [markdown]
// ## Data

// %% [markdown]
// TODO
//
// To convert from sas transport file format with extension`.xpt` to CSV we can use `xport` module from python PyPI packages:
// ```bash
// pip install xport
// ```
// and use the `xport` module as a command-line tool to convert an XPT file to CSV file:
//
// ```bash
// python -m xport paxraw_d.xpt > paxraw_d.csv
// ```

// %% [markdown]
// ## Reading the data

// %%
val spark = sparkSession
// Out:
// spark: org.apache.spark.sql.SparkSession = org.apache.spark.sql.SparkSession@3abdda32

// %%
import org.apache.spark.sql.types._
import org.apache.spark.sql.functions._
// Out:
// import org.apache.spark.sql.types._
// import org.apache.spark.sql.functions._

// %%
val PaxSchema = StructType(
    StructField("SEQN", FloatType, false) ::
    StructField("PAXSTAT", FloatType, false) ::
    StructField("PAXCAL", FloatType, false) ::
    StructField("PAXDAYSAS", FloatType, false) ::
    StructField("PAXN", FloatType, false) ::
    StructField("PAXHOUR", FloatType, false) ::
    StructField("PAXMINUT", FloatType, false) ::
    StructField("PAXINTEN", FloatType, false) ::
    StructField("PAXSTEP", StringType, true) :: Nil
)
// Out:
// PaxSchema: org.apache.spark.sql.types.StructType = StructType(StructField(SEQN,FloatType,false), StructField(PAXSTAT,FloatType,false), StructField(PAXCAL,FloatType,false), StructField(PAXDAYSAS,FloatType,false), StructField(PAXN,FloatType,false), StructField(PAXHOUR,FloatType,false), StructField(PAXMINUT,FloatType,false), StructField(PAXINTEN,FloatType,false), StructField(PAXSTEP,StringType,true))

// %% [markdown]
// TODO note on `nan` values in `PAXSTEP` column

// %%
val PaxDF = spark.read
  .format("csv")
  .schema(PaxSchema)
  .option("header", true)
  .load("./notebooks/spark-notebooks-gallery/gallery/physical-activity-monitor/data/paxraw_d.csv")
  .withColumn("PAXSTEP", when($"PAXSTEP" === "nan", null).otherwise($"PAXSTEP".cast(DoubleType)))
  .select($"SEQN".cast(IntegerType),
          $"PAXSTAT".cast(IntegerType),
          $"PAXCAL".cast(IntegerType),
          $"PAXDAYSAS".cast(IntegerType),
          $"PAXN".cast(IntegerType),
          $"PAXHOUR".cast(IntegerType),
          $"PAXMINUT".cast(IntegerType),
          $"PAXINTEN".cast(IntegerType),
          $"PAXSTEP".cast(IntegerType))
  .filter(!isnull($"PAXSTEP"))
// Out:
// PaxDF: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [SEQN: int, PAXSTAT: int ... 7 more fields]

// %%
PaxDF.write.format("parquet").save("./notebooks/spark-notebooks-gallery/gallery/physical-activity-monitor/data/paxraw_d.parquet")

// %%
val PaxDF = spark.read
  .format("parquet")
  .load("./notebooks/spark-notebooks-gallery/gallery/physical-activity-monitor/data/paxraw_d.parquet")
  .withColumn("datetime", concat($"PAXDAYSAS", lit(".01.2005 "), $"PAXHOUR", lit(":"), $"PAXMINUT"))
  .withColumn("time", unix_timestamp($"datetime", "d.MM.yyyy HH:mm"))
  .withColumn("datetime", from_unixtime($"time"))
// Out:
// PaxDF: org.apache.spark.sql.DataFrame = [SEQN: int, PAXSTAT: int ... 9 more fields]

// %% [markdown]
// Let's take a closer look at the data.

// %%
PaxDF.describe("PAXSTEP").show
// Out:
// +-------+------------------+
// |summary|           PAXSTEP|
// +-------+------------------+
// |  count|          74874033|
// |   mean|22.429516051312476|
// | stddev| 708.6893633662772|
// |    min|                 0|
// |    max|             32767|
// +-------+------------------+

// %% [markdown]
// `PAXSTEP` - is the step count per minute recorded by the physical activity monitor.
// The values like over `500` steps per minutes seems unreliable to me.
// Let's excluse those devices that have recorded more than `500` steps per minute.

// %%
PaxDF.where($"PAXSTEP" > 500).select($"SEQN").distinct.count
// Out:
// res4: Long = 166
// 166

// %%
val broadcastedBlackList = spark.sparkContext.broadcast(
  PaxDF.where($"PAXSTEP" > 500).select($"SEQN").distinct
  .collect.map(_(0).asInstanceOf[Int]).toSet
)
// Out:
// broadcastedBlackList: org.apache.spark.broadcast.Broadcast[scala.collection.immutable.Set[Int]] = Broadcast(8)

// %%
def inBlacklistUDF = udf((seqNum: Int) => {
  broadcastedBlackList.value.contains(seqNum)
})
// Out:
// inBlacklistUDF: org.apache.spark.sql.expressions.UserDefinedFunction

// %%
val PaxUnreliable = PaxDF.where(inBlacklistUDF($"SEQN"))
// Out:
// PaxUnreliable: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [SEQN: int, PAXSTAT: int ... 9 more fields]

// %%
val PaxReliable = PaxDF.where(!inBlacklistUDF($"SEQN"))
// Out:
// PaxReliable: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [SEQN: int, PAXSTAT: int ... 9 more fields]

// %%
val seqNums = PaxReliable.select($"SEQN").distinct
  .sample(false, 0.01)
  .limit(5)
  .collect
  .map(_(0).asInstanceOf[Int]).toList
// Out:
// seqNums: List[Int] = List(35982, 37152, 34805, 37472, 31769)

// %% [markdown]
// TODO show for both Reliable and Unreliable data.

// %%
CustomPlotlyChart(PaxReliable.where($"SEQN" === seqNums(1)),
                  layout="""{title: 'Physical activity monitor data', 
                           yaxis: {title: 'Device Step Count per 1 min'},
                           showlegend: false}""",
                  dataOptions="""{
                    colorscale: 'Electric',
                    autocolorscale: true
                  }""",
                  dataSources="""{
                    x: 'datetime',
                    y: 'PAXSTEP'
                  }""",
                 maxPoints=2000)
// Out:
// res49: notebook.front.widgets.charts.CustomPlotlyChart[org.apache.spark.sql.Dataset[org.apache.spark.sql.Row]] = <CustomPlotlyChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon6ad0acc867432c565cf35b9d70a31ff9&quot;,&quot;dataInit&quot;:[{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:00:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:1,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:0,&quot;time&quot;:1104699600,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:01:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:2,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:1,&quot;time&quot;:1104699660,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:02:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:3,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:2,&quot;time&quot;:1104699720,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:03:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:4,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:3,&quot;time&quot;:1104699780,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:04:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:5,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:4,&quot;time&quot;:1104699840,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:05:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:6,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:5,&quot;time&quot;:1104699900,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:06:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:7,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:6,&quot;time&quot;:1104699960,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:07:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:8,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:7,&quot;time&quot;:1104700020,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:08:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:9,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:8,&quot;time&quot;:1104700080,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:09:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:10,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:9,&quot;time&quot;:1104700140,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:10:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:11,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:10,&quot;time&quot;:1104700200,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:11:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:12,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:11,&quot;time&quot;:1104700260,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:12:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:13,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:12,&quot;time&quot;:1104700320,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:0,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 00:13:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:38910,&quot;PAXN&quot;:14,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:13,&quot;time&quot;:1104700 ...

// %% [markdown]
// Let's see on steps count distribution

// %% [markdown]
// TODO show for both Reliable and Unreliable data.

// %%
CustomPlotlyChart(PaxReliable.sample(withReplacement=false, 0.001),
                  layout="""{title: 'Steps count distribution', 
                             yaxis: {type: 'log'},
                             xaxis: {title: 'Step Count per minute'},
                             bargap: 0.02}""",
                  dataOptions="{type: 'histogram', opacity: 0.7}",
                  dataSources="{x: 'PAXSTEP'}",
                  maxPoints=5000)
// Out:
// res9: notebook.front.widgets.charts.CustomPlotlyChart[org.apache.spark.sql.Dataset[org.apache.spark.sql.Row]] = <CustomPlotlyChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon6620f24f946112ce6a4a349341e12d72&quot;,&quot;dataInit&quot;:[{&quot;PAXINTEN&quot;:1088,&quot;datetime&quot;:&quot;2005-01-02 06:34:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:395,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:34,&quot;time&quot;:1104636840,&quot;PAXDAYSAS&quot;:2,&quot;PAXHOUR&quot;:6,&quot;PAXSTEP&quot;:6},{&quot;PAXINTEN&quot;:479,&quot;datetime&quot;:&quot;2005-01-02 12:04:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:725,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:4,&quot;time&quot;:1104656640,&quot;PAXDAYSAS&quot;:2,&quot;PAXHOUR&quot;:12,&quot;PAXSTEP&quot;:21},{&quot;PAXINTEN&quot;:648,&quot;datetime&quot;:&quot;2005-01-02 20:19:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:1220,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:19,&quot;time&quot;:1104686340,&quot;PAXDAYSAS&quot;:2,&quot;PAXHOUR&quot;:20,&quot;PAXSTEP&quot;:31},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-02 22:39:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:1360,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:39,&quot;time&quot;:1104694740,&quot;PAXDAYSAS&quot;:2,&quot;PAXHOUR&quot;:22,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-03 23:33:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:2854,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:33,&quot;time&quot;:1104784380,&quot;PAXDAYSAS&quot;:3,&quot;PAXHOUR&quot;:23,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-05 23:14:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:5715,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:14,&quot;time&quot;:1104956040,&quot;PAXDAYSAS&quot;:5,&quot;PAXHOUR&quot;:23,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-06 11:59:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:6480,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:59,&quot;time&quot;:1105001940,&quot;PAXDAYSAS&quot;:6,&quot;PAXHOUR&quot;:11,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-07 01:24:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:7285,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:24,&quot;time&quot;:1105050240,&quot;PAXDAYSAS&quot;:7,&quot;PAXHOUR&quot;:1,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-07 09:51:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:7792,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:51,&quot;time&quot;:1105080660,&quot;PAXDAYSAS&quot;:7,&quot;PAXHOUR&quot;:9,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-07 20:48:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:8449,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:48,&quot;time&quot;:1105120080,&quot;PAXDAYSAS&quot;:7,&quot;PAXHOUR&quot;:20,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-07 21:25:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:8486,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:25,&quot;time&quot;:1105122300,&quot;PAXDAYSAS&quot;:7,&quot;PAXHOUR&quot;:21,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-01 14:02:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:9483,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:2,&quot;time&quot;:1104577320,&quot;PAXDAYSAS&quot;:1,&quot;PAXHOUR&quot;:14,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-01 23:55:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35660,&quot;PAXN&quot;:10076,&quot;PAXSTAT&quot;:1,&quot;PAXMINUT&quot;:55,&quot;time&quot;:1104612900,&quot;PAXDAYSAS&quot;:1,&quot;PAXHOUR&quot;:23,&quot;PAXSTEP&quot;:0},{&quot;PAXINTEN&quot;:0,&quot;datetime&quot;:&quot;2005-01-05 00:02:00&quot;,&quot;PAXCAL&quot;:1,&quot;SEQN&quot;:35662,&quot;PAXN&quot;:3,&quot;PAXS ...

// %% [markdown]
// ## Bucketize

// %%
import org.apache.spark.ml.feature.Bucketizer

val splits = Array(0, 1, 4, 10, 30, 40, 60, 80, 100, 120, Double.PositiveInfinity)

val bucketizer = new Bucketizer()
  .setInputCol("PAXSTEP")
  .setOutputCol("activityLevel")
  .setSplits(splits)
// Out:
// import org.apache.spark.ml.feature.Bucketizer
// splits: Array[Double] = Array(0.0, 1.0, 4.0, 10.0, 30.0, 40.0, 60.0, 80.0, 100.0, 120.0, Infinity)
// bucketizer: org.apache.spark.ml.feature.Bucketizer = bucketizer_2e76cd2fb8b6

// %%
val bucketedPax = bucketizer
  .transform(PaxReliable.withColumn("PAXSTEP", $"PAXSTEP".cast(DoubleType)))
  .withColumn("activityLevel", $"activityLevel".cast(IntegerType))
// Out:
// bucketedPax: org.apache.spark.sql.DataFrame = [SEQN: int, PAXSTAT: int ... 10 more fields]

// %%
bucketedPax.where($"activityLevel" > 0).limit(10).show
// Out:
// +-----+-------+------+---------+----+-------+--------+--------+-------+-------------------+----------+-------------+
// | SEQN|PAXSTAT|PAXCAL|PAXDAYSAS|PAXN|PAXHOUR|PAXMINUT|PAXINTEN|PAXSTEP|           datetime|      time|activityLevel|
// +-----+-------+------+---------+----+-------+--------+--------+-------+-------------------+----------+-------------+
// |35660|      1|     1|        2| 395|      6|      34|    1088|    6.0|2005-01-02 06:34:00|1104636840|            2|
// |35660|      1|     1|        2| 396|      6|      35|     786|   25.0|2005-01-02 06:35:00|1104636900|            3|
// |35660|      1|     1|        2| 397|      6|      36|     786|   15.0|2005-01-02 06:36:00|1104636960|            3|
// |35660|      1|     1|        2| 399|      6|      38|     107|   12.0|2005-01-02 06:38:00|1104637080|            3|
// |35660|      1|     1|        2| 400|      6|      39|     374|   37.0|2005-01-02 06:39:00|1104637140|            4|
// |35660|      1|     1|        2| 401|      6|      40|     328|   38.0|2005-01-02 06:40:00|1104637200|            4|
// |35660|      1|     1|        2| 402|      6|      41|     149|   16.0|2005-01-02 06:41:00|1104637260|            3|
// |35660|      1|     1|        2| 403|      6|      42|     203|   22.0|2005-01-02 06:42:00|1104637320|            3|
// |35660|      1|     1|        2| 404|      6|      43|     277|   16.0|2005-01-02 06:43:00|1104637380|            3|
// |35660|      1|     1|        2| 405|      6|      44|     584|   31.0|2005-01-02 06:44:00|1104637440|            4|
// +-----+-------+------+---------+----+-------+--------+--------+-------+-------------------+----------+-------------+

// %% [markdown]
// ## Building a Transition Matrix

// %%
import org.apache.spark.sql.expressions.Window
// Out:
// import org.apache.spark.sql.expressions.Window

// %%
val customers = sc.parallelize(List(("Alice", Array(Array(25.0, 12.0), Array(43.0, 50.00))),
                                    ("Bob",  Array(Array(27.00, 13.0), Array(12.0, 25.0))))).
                               toDF("name", "amountSpent")
// Out:
// customers: org.apache.spark.sql.DataFrame = [name: string, amountSpent: array<array<double>>]

// %%
customers.schema
// Out:
// res46: org.apache.spark.sql.types.StructType = StructType(StructField(name,StringType,true), StructField(amountSpent,ArrayType(ArrayType(DoubleType,false),true),true))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonf5a765d9cf3bdccc499751e211ec02b4&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;2140659215&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul2140659215"><li>
//               <a href="#tab2140659215-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab2140659215-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab2140659215"><div class="tab-pane" id="tab2140659215-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon41d9097b81fa7be3c461b6f037f346d7&quot;,&quot;dataInit&quot;:[{&quot;name&quot;:&quot;name&quot;,&quot;dataType&quot;:&quot;StringType&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:&quot;{}&quot;},{&quot;name&quot;:&quot;amountSpent&quot;,&quot;dataType&quot;:&quot;ArrayType(ArrayType(DoubleType,false),true)&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:&quot;{}&quot;}],&quot;genId&quot;:&quot;1417894641&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["name","dataType","nullable","metadata"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon55490613397ceca291d274f5835a92a3&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond264febc0be02dd5444bf16104f43da7&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab2140659215-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonbaa11578626f4f9db4c0f9be66d08e57&quot;,&quot;dataInit&quot;:[{&quot;name&quot;:&quot;name&quot;,&quot;dataType&quot;:&quot;StringType&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:&quot;{}&quot;},{&quot;name&quot;:&quot;amountSpent&quot;,&quot;dataType&quot;:&quot;ArrayType(ArrayType(DoubleType,false),true)&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:&quot;{}&quot;}],&quot;genId&quot;:&quot;1960758188&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonee6a0b99ca40fd631233b55e7bedd617&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond6cb70aead1e915d5bb0ddcae888004e&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %% [markdown]
// 1. use `Window Function` to collect previous minute activity

// %%
val windowSpec = Window.partitionBy("SEQN").orderBy("time")
// Out:
// windowSpec: org.apache.spark.sql.expressions.WindowSpec = org.apache.spark.sql.expressions.WindowSpec@2d093132

// %%
PaxSmall.show(4)
// Out:
// +-----+-------+------+---------+----+-------+--------+--------+-------+-------------------+----------+-------------+
// | SEQN|PAXSTAT|PAXCAL|PAXDAYSAS|PAXN|PAXHOUR|PAXMINUT|PAXINTEN|PAXSTEP|           datetime|      time|activityLevel|
// +-----+-------+------+---------+----+-------+--------+--------+-------+-------------------+----------+-------------+
// |35982|      1|     1|        7|   1|      0|       0|       0|    0.0|2005-01-07 00:00:00|1105045200|            0|
// |35982|      1|     1|        7|   2|      0|       1|       0|    0.0|2005-01-07 00:01:00|1105045260|            0|
// |35982|      1|     1|        7|   3|      0|       2|       0|    0.0|2005-01-07 00:02:00|1105045320|            0|
// |35982|      1|     1|        7|   4|      0|       3|       0|    0.0|2005-01-07 00:03:00|1105045380|            0|
// +-----+-------+------+---------+----+-------+--------+--------+-------+-------------------+----------+-------------+
// only showing top 4 rows

// %%
val df = PaxSmall
  .select($"SEQN", $"activityLevel", $"time")
  .withColumn("previousMinuteActivity", lag("activityLevel", 1).over(windowSpec))
  .withColumn("previousMinuteActivity", when(isnull($"previousMinuteActivity"), -1).otherwise($"previousMinuteActivity"))
// Out:
// df: org.apache.spark.sql.DataFrame = [SEQN: int, activityLevel: int ... 2 more fields]

// %%
def initTransitionMatrix = udf{ (currentActivityLevel: Int, previousActivityLevel: Int, size: Int) => {
  val W = Array.fill(size, size)(0.0)
  if (previousActivityLevel >= 0)
    W.updated(currentActivityLevel, W(currentActivityLevel).updated(previousActivityLevel, 1.0))
  else
    W
}}
// Out:
// initTransitionMatrix: org.apache.spark.sql.expressions.UserDefinedFunction

// %%
val dfW = df.withColumn("W", initTransitionMatrix($"activityLevel", $"previousMinuteActivity", lit(10)))
// Out:
// dfW: org.apache.spark.sql.DataFrame = [SEQN: int, activityLevel: int ... 3 more fields]

// %%
dfW.show(5)
// Out:
// +-----+-------------+----------+----------------------+--------------------+
// | SEQN|activityLevel|      time|previousMinuteActivity|                   W|
// +-----+-------------+----------+----------------------+--------------------+
// |35982|            0|1104526800|                    -1|[WrappedArray(0.0...|
// |35982|            0|1104526860|                     0|[WrappedArray(1.0...|
// |35982|            0|1104526920|                     0|[WrappedArray(1.0...|
// |35982|            0|1104526980|                     0|[WrappedArray(1.0...|
// |35982|            0|1104527040|                     0|[WrappedArray(1.0...|
// +-----+-------------+----------+----------------------+--------------------+
// only showing top 5 rows

// %%
val arr = Array.fill(4,4)(0.0)
// Out:
// arr: Array[Array[Double]] = Array(Array(0.0, 0.0, 0.0, 0.0), Array(0.0, 0.0, 0.0, 0.0), Array(0.0, 0.0, 0.0, 0.0), Array(0.0, 0.0, 0.0, 0.0))

// %%
arr.updated(1, arr(1).updated(2, -1))
// Out:
// res84: Array[Array[_ >: Double <: AnyVal]] = Array(Array(0.0, 0.0, 0.0, 0.0), Array(0.0, 0.0, -1, 0.0), Array(0.0, 0.0, 0.0, 0.0), Array(0.0, 0.0, 0.0, 0.0))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon041655cbb408a2cc00fb081f7e4e6d06&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;16424184&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul16424184"><li>
//               <a href="#tab16424184-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab16424184-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab16424184"><div class="tab-pane" id="tab16424184-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon7d6f8f6a47e8b2af0edd2f9e90446ece&quot;,&quot;dataInit&quot;:[{},{},{},{}],&quot;genId&quot;:&quot;1560909085&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":[],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond371efdd79c853cab9745b61e113f42d&quot;,&quot;initialValue&quot;:&quot;4&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon8a78d92b3130b1703046db4cddab8b59&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab16424184-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonc071183fd3037c3a489297b8fdbe9b6f&quot;,&quot;dataInit&quot;:[{},{},{},{}],&quot;genId&quot;:&quot;957285249&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonf588ace25066281443ccb7bf5ca6930b&quot;,&quot;initialValue&quot;:&quot;4&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anondfbecf8b705eab4f0f1a4ac6cb671614&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>
